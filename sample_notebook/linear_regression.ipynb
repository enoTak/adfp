# %%
import numpy as np
from adfp import Variable
import adfp.functions as F

import matplotlib.pyplot as plt

# %%
 np.random.seed(0)
 x = np.sort(np.random.rand(100, 1), axis=0)
 y = 5 + 2 * x + np.random.rand(100, 1)
 x, y = Variable(x), Variable(y)

# %%
W = Variable(np.zeros((1, 1)))
b = Variable(np.zeros(1))


def predict(x):
    y = x.dot(W) + b
    return y

# %%
def mse_simple(x0, x1):
    diff = x0 - x1
    return F.sum(diff ** 2) / len(diff)

# %%
lr = 0.1
iters = 100

for i in range(iters):
    y_pred = predict(x)
    loss = mse_simple(y, y_pred)

    W.cleargrad()
    b.cleargrad()
    loss.backward()

    W.data -= lr * W.grad.data
    b.data -= lr * b.grad.data
    
    print(W, b, loss)
# Out:
# variable([[0.64225628]]) variable([1.29473389]) variable(42.2547740655632)
# variable([[1.12269431]]) variable([2.26979003]) variable(23.955616340482283)
# variable([[1.48146679]]) variable([3.00440532]) variable(13.604544920739368)
# variable([[1.7487713]]) variable([3.55817247]) variable(7.749121753989504)
# variable([[1.94731839]]) variable([3.9759102]) variable(4.436563126816414)
# variable([[2.09418776]]) variable([4.29132602]) variable(2.562326453969445)
# variable([[2.20222423]]) variable([4.52977089]) variable(1.5016550581990726)
# variable([[2.28108774]]) variable([4.71031099]) variable(0.9011708995623089)
# variable([[2.33804287]]) variable([4.84728583]) variable(0.5609943334092466)
# variable([[2.37855275]]) variable([4.9514801]) variable(0.3680681665159424)
# variable([[2.40672567]]) variable([5.03100495]) variable(0.25844411469172895)
# variable([[2.42565095]]) variable([5.09196083]) variable(0.19595110194460935)
# variable([[2.43765163]]) variable([5.13893599]) variable(0.16012952929214858)
# variable([[2.44447439]]) variable([5.17538134]) variable(0.13940660229066135)
# variable([[2.44743248]]) variable([5.20389247]) variable(0.12723612937170636)
# variable([[2.44751317]]) variable([5.22642167]) variable(0.1199150972678021)
# variable([[2.44545858]]) variable([5.24443739]) variable(0.11534867251409348)
# variable([[2.44182645]]) variable([5.25904425]) variable(0.11235165590599142)
# variable([[2.43703588]]) variable([5.27107319]) variable(0.11025336785535592)
# variable([[2.43140167]]) variable([5.28114933]) variable(0.1086741616788602)
# variable([[2.42516022]]) variable([5.289743]) variable(0.10739901384190509)
# variable([[2.41848896]]) variable([5.29720813]) variable(0.10630602330497074)
# variable([[2.41152095]]) variable([5.30381105]) variable(0.10532596880477403)
# variable([[2.40435593]]) variable([5.30975228]) variable(0.1044194332672107)
# variable([[2.39706855]]) variable([5.31518277]) variable(0.10356386462430081)
# variable([[2.38971461]]) variable([5.32021626]) variable(0.10274625690901415)
# variable([[2.38233572]]) variable([5.32493842]) variable(0.10195901032150406)
# variable([[2.37496287]]) variable([5.3294139]) variable(0.10119758940405829)
# variable([[2.36761899]]) variable([5.33369144]) variable(0.10045919827497589)
# variable([[2.36032104]]) variable([5.33780791]) variable(0.09974203114041195)
# variable([[2.35308143]]) variable([5.34179116]) variable(0.09904484820196638)
# variable([[2.34590918]]) variable([5.34566234]) variable(0.09836673562041082)
# variable([[2.33881075]]) variable([5.34943747]) variable(0.09770696959030502)
# variable([[2.33179069]]) variable([5.3531288]) variable(0.09706493930640368)
# variable([[2.32485213]]) variable([5.35674568]) variable(0.09644010324471754)
# variable([[2.08374383]]) variable([5.47923827]) variable(0.08003098134219053)
# variable([[2.08009332]]) variable([5.48108825]) variable(0.07986006429481216)
# variable([[2.07649177]]) variable([5.48291343]) variable(0.0796937006515002)
# variable([[2.07293851]]) variable([5.48471412]) variable(0.07953176910493685)
# variable([[2.0694329]]) variable([5.48649068]) variable(0.0793741515795546)
# variable([[2.06597431]]) variable([5.4882434]) variable(0.07922073314543926)
# variable([[2.0625621]]) variable([5.48997262]) variable(0.07907140193452657)
# variable([[2.05919564]]) variable([5.49167866]) variable(0.07892604905903115)
# variable([[2.05587433]]) variable([5.49336181]) variable(0.07878456853204929)
# variable([[2.05259756]]) variable([5.49502239]) variable(0.07864685719027602)
# variable([[2.04936474]]) variable([5.4966607]) variable(0.07851281461878191)
# variable([[2.04617527]]) variable([5.49827704]) variable(0.0783823430777934)
# variable([[2.04302857]]) variable([5.49987171]) variable(0.078255347431424)
# variable([[2.03992407]]) variable([5.50144499]) variable(0.07813173507830393)
# variable([[2.0368612]]) variable([5.50299717]) variable(0.07801141588405827)
# variable([[2.0338394]]) variable([5.50452854]) variable(0.07789430211558349)
# variable([[2.03085813]]) variable([5.50603937]) variable(0.07778030837707517)
# variable([[2.02791684]]) variable([5.50752994]) variable(0.07766935154776014)
# variable([[2.025015]]) variable([5.50900052]) variable(0.07756135072128717)

# %%
y_pred = predict(x)
plt.plot(x.data, y_pred.data, color="red")
plt.scatter(x.data, y.data)
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
from adfp import plot_dot_graph

# %%
plot_dot_graph(loss)

# %%
from adfp.model.evaluation import mean_square_error

# %%
np.random.seed(0)
x = np.sort(np.random.rand(100, 1), axis=0)
y = np.sin(2 * np.pi * x) + np.random.rand(100, 1)

I, H, O = 1, 10, 1
W1 = Variable(0.01 * np.random.randn(I, H))
b1 = Variable(np.zeros(H))
W2 = Variable(0.01 * np.random.randn(H, O))
b2 = Variable(np.zeros(O))


def predict(x):
    y = F.linear(x, W1, b1)
    y = F.sigmoid(y)
    y = F.linear(y, W2, b2)
    return y


lr = 0.2
iters = 10000

for i in range(iters):
    y_pred = predict(x)
    loss = mean_square_error(y, y_pred)

    W1.cleargrad()
    b1.cleargrad()
    W2.cleargrad()
    b2.cleargrad()
    loss.backward()

    W1.data -= lr * W1.grad.data
    b1.data -= lr * b1.grad.data
    W2.data -= lr * W2.grad.data
    b2.data -= lr * b2.grad.data

    if i % 1000 == 0:
        print(f'iter: {i}, loss: {loss}')
# Out:
# iter: 0, loss: variable(0.8905591908908628)
# iter: 1000, loss: variable(0.2519474075970769)
# iter: 2000, loss: variable(0.2477881714284897)
# iter: 3000, loss: variable(0.23488650660751614)
# iter: 4000, loss: variable(0.20092244057570466)
# iter: 5000, loss: variable(0.14002748666646425)
# iter: 6000, loss: variable(0.08467092842761373)
# iter: 7000, loss: variable(0.07765580756896938)
# iter: 8000, loss: variable(0.07673947889445973)
# iter: 9000, loss: variable(0.07619143992295949)

# %%
y_pred = predict(x)
plt.plot(x, y_pred.data, color="red")
plt.scatter(x, y)
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')
